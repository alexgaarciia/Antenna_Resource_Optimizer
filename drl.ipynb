# %%
import numpy as np

from mobility_utils import generate_mobility
from radio_utils import compute_sinr_dl

import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO

# %%
class CellularEnv(gym.Env):
    def __init__(self,
                 n_users=5,
                 n_antennas=13,
                 radios_per_user=2,
                 sim_time=300,
                 time_step=0.5,
                 map_limit=1000,
                 seed=0):
        super(CellularEnv, self).__init__()

        # Definition of the environment parameters
        self.n_users = n_users
        self.n_antennas = n_antennas
        self.radios_per_user = radios_per_user
        self.sim_time = sim_time
        self.time_step = time_step
        self.map_limit = map_limit
        self.max_steps = int(sim_time / time_step)
        self.current_step = 0
        self.seed(seed)

        # Definition of the network parameters
        self.alpha_loss = 4
        self.p_macro = 40
        self.p_femto = 0.1
        self.n_macro = 3
        self.n_femto = n_antennas - self.n_macro
        self.macro_bw = 20e6
        self.femto_bw = 1e9
        self.noise = 2.5e-14
        self.b = 1 * np.sqrt(2 / np.pi)

        # Set the observation space: [user_positions (x,y) | bs_loads ]
        # This defines how does the agent observe the environment
        obs_low = np.array([0] * (2 * self.n_users) + [0] * self.n_antennas, dtype=np.float32)
        obs_high = np.array([self.map_limit] * (2 * self.n_users) + [self.n_users] * self.n_antennas, dtype=np.float32)
        self.observation_space = spaces.Box(low=obs_low, high=obs_high, dtype=np.float32)

        # Set the action space: for each user, pick radios_per_user base stations (by index)
        # This defines all the possible actions the agent can take
        self.action_space = spaces.MultiDiscrete([self.n_antennas] * self.n_users * self.radios_per_user)

        # Internal simulation state variables
        self.base_stations = None  # will contain the positions of the base stations
        self.user_positions = None  # will contain the positions of the users
        self.bs_user_count = None  # will contain the number of users per base station
        self.throughputs = None  # will contain the throughput of each user

        # Mobility traces 
        self.sim_times = np.arange(0, self.sim_time + self.time_step, self.time_step)
        self.mobility_traces = None  # will contain the positions of the users over time

        # Initialize the environment
        self.reset()

    def seed(self, seed=None):
        np.random.seed(seed)

    def reset(self, seed=None, options=None):
        """
        Resets the environment to an initial state and returns the initial observation.
        """
        if seed is not None:
            self.seed(seed)

        # Each episode starts in the first time step (t=0)
        self.current_step = 0

        # Reinitialize base stations: positions randomly over the map
        # Create an array full of zeros with as many row as antennas and 3 columns (x, y, power)
        self.base_stations = np.zeros((self.n_antennas, 3))
        # Macro cells are filled with random positions and power defined in the init
        self.base_stations[:self.n_macro, 0] = np.random.uniform(0, self.map_limit, self.n_macro)
        self.base_stations[:self.n_macro, 1] = np.random.uniform(0, self.map_limit, self.n_macro)
        self.base_stations[:self.n_macro, 2] = self.p_macro
        # Femto cells are filled with random positions and power defined in the init
        self.base_stations[self.n_macro:, 0] = np.random.uniform(0, self.map_limit, self.n_femto)
        self.base_stations[self.n_macro:, 1] = np.random.uniform(0, self.map_limit, self.n_femto)
        self.base_stations[self.n_macro:, 2] = self.p_femto

        # Generate real mobility for each user
        sim_input = {
            'V_POSITION_X_INTERVAL': [0, self.map_limit],
            'V_POSITION_Y_INTERVAL': [0, self.map_limit],
            'V_SPEED_INTERVAL': [1, 10],
            'V_PAUSE_INTERVAL': [0, 3],
            'V_WALK_INTERVAL': [30.0, 60.0],
            'V_DIRECTION_INTERVAL': [-180, 180],
            'SIMULATION_TIME': self.sim_time,
            'NB_NODES': self.n_users
        }
        s_mobility = generate_mobility(sim_input)

        # Interpolate user positions for each timestep
        self.mobility_traces = np.zeros((self.n_users, len(self.sim_times), 2))
        for u, node in enumerate(s_mobility["VS_NODE"]):
            x = np.interp(self.sim_times, node["V_TIME"], node["V_POSITION_X"])
            y = np.interp(self.sim_times, node["V_TIME"], node["V_POSITION_Y"])
            self.mobility_traces[u, :, 0] = x
            self.mobility_traces[u, :, 1] = y

        self.user_positions = self.mobility_traces[:, 0, :]
        self.bs_user_count = np.zeros(self.n_antennas, dtype=int)
        self.throughputs = np.zeros(self.n_users, dtype=float)

        obs = self._get_obs()
        return obs, {}

    def step(self, action):
        """
        Executes one time step within the environment given the action.
        """
        done = False
        info = {}

        # Update user positions (mobility)
        if self.current_step < len(self.sim_times):
            self.user_positions = self.mobility_traces[:, self.current_step, :]
        else:
            # Just hold last positions
            pass

        # Action: (n_users * radios_per_user, ), reshape
        associations = np.array(action).reshape((self.n_users, self.radios_per_user))

        # Reset per-BS user counts
        self.bs_user_count = np.zeros(self.n_antennas, dtype=int)
        user_bs_sets = [set() for _ in range(self.n_antennas)]
        # For each user, increment BS count for each association
        for u in range(self.n_users):
            for radio in range(self.radios_per_user):
                bs_idx = associations[u, radio]
                # Avoid duplicates: only count once per user per BS
                if u not in user_bs_sets[bs_idx]:
                    self.bs_user_count[bs_idx] += 1
                    user_bs_sets[bs_idx].add(u)

        # Throughput calculation
        self.throughputs = np.zeros(self.n_users, dtype=float)
        for u in range(self.n_users):
            user_rate = 0
            user_pos = self.user_positions[u]
            for radio in range(self.radios_per_user):
                bs_idx = associations[u, radio]
                if bs_idx >= self.n_antennas:
                    continue
                sinr_db = compute_sinr_dl(
                    user_pos,
                    self.base_stations,
                    bs_idx,
                    self.alpha_loss,
                    self.p_macro,
                    self.p_femto,
                    self.n_macro,
                    self.noise,
                    self.b
                )
                sinr_linear = 10 ** (sinr_db / 10)
                is_macro = bs_idx < self.n_macro
                bw = self.macro_bw if is_macro else self.femto_bw
                rate = (bw / max(self.bs_user_count[bs_idx], 1)) * np.log2(1 + sinr_linear)
                user_rate += rate
            self.throughputs[u] = user_rate

        # Reward: proportional fairness 
        # epsilon = 1e-9
        # reward = np.sum(np.log(self.throughputs + epsilon))
        reward = np.mean(self.throughputs)


        # Next observation 
        obs = self._get_obs()

        # Check for end of episode 
        self.current_step += 1
        terminated = False
        truncated= False
        if self.current_step >= self.max_steps:
            truncated = True

        return obs, reward, terminated, truncated, info

    def _get_obs(self):
        """
        Builds the observation vector: [user_positions | bs_user_count].
        """
        obs = np.concatenate([self.user_positions.flatten(), self.bs_user_count])
        return obs.astype(np.float32)

# %%
import scipy
mat = scipy.io.loadmat("nice_setup_Proteus.mat")
base_stations = mat["BaseStations"]
n_points = base_stations.shape[0]  # = 7

env = CellularEnv(
    n_users=5,
    n_antennas=n_points,
    radios_per_user=2,
    sim_time=300,
    time_step=0.5,
    map_limit=1000,
    seed=0
)

# Crear el modelo PPO
model = PPO('MlpPolicy', env, verbose=1)

# Entrenar el agente
model.learn(total_timesteps=20000)

# Guardar modelo
model.save("ppo_cellular_multi_connectivity")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\algar\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 600      |
# |    ep_rew_mean     | 1.16e+10 |
# | time/              |          |
# |    fps             | 122      |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2048     |
# ---------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 600            |
# |    ep_rew_mean          | 1.59e+10       |
# | time/                   |                |
# |    fps                  | 109            |
# |    iterations           | 2              |
# |    time_elapsed         | 37             |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | -1.0797521e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -19.5          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 6.64e+16       |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -1.21e-07      |
# |    value_loss           | 1.3e+17        |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 600           |
# |    ep_rew_mean          | 1.65e+10      |
# | time/                   |               |
# |    fps                  | 106           |
# |    iterations           | 3             |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | -8.090865e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -19.5         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.54e+17      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -3.8e-08      |
# |    value_loss           | 6.1e+17       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 600           |
# |    ep_rew_mean          | 1.73e+10      |
# | time/                   |               |
# |    fps                  | 104           |
# |    iterations           | 4             |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | -9.051291e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -19.5         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.07e+17      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -4.06e-08     |
# |    value_loss           | 5.24e+17      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 600           |
# |    ep_rew_mean          | 1.77e+10      |
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 5             |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | -8.178176e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -19.5         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.85e+17      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -4.24e-08     |
# |    value_loss           | 5.63e+17      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 600           |
# |    ep_rew_mean          | 1.79e+10      |
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 6             |
# |    time_elapsed         | 122           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | -8.731149e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -19.5         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.69e+17      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -6.22e-08     |
# |    value_loss           | 7.88e+17      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 600           |
# |    ep_rew_mean          | 1.82e+10      |
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 7             |
# |    time_elapsed         | 142           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | -9.546056e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -19.5         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.2e+17       |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -8.09e-08     |
# |    value_loss           | 4.63e+17      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 600           |
# |    ep_rew_mean          | 1.82e+10      |
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 8             |
# |    time_elapsed         | 163           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | -8.643838e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -19.5         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.21e+17      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -5.29e-08     |
# |    value_loss           | 6.5e+17       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 600           |
# |    ep_rew_mean          | 1.85e+10      |
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 9             |
# |    time_elapsed         | 183           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | -8.119969e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -19.5         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.91e+17      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -1.94e-08     |
# |    value_loss           | 5.57e+17      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          |

#  [3 0]
#  [3 0]
#  [6 5]]
# Step 292: User associations (user x radio):
# [[3 5]
#  [1 1]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 293: User associations (user x radio):
# [[0 5]
#  [1 3]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 294: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [3 0]
#  [6 0]
#  [6 5]]
# Step 295: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 296: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 297: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 298: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 299: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 300: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 301: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 302: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 303: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 304: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 305: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 306: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 307: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 308: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 309: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 310: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 311: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 312: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 313: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 314: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 315: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 316: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 317: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 318: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [4 0]
#  [6 0]
#  [6 5]]
# Step 319: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 320: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 321: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 322: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 323: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 324: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 325: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 326: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 327: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 328: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 329: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 330: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 331: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 332: User associations (user x radio):
# [[4 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 333: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [4 0]
#  [3 0]
#  [6 5]]
# Step 334: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [3 0]
#  [3 0]
#  [6 2]]
# Step 335: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [3 0]
#  [3 0]
#  [6 2]]
# Step 336: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [3 0]
#  [3 0]
#  [6 2]]
# Step 337: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [3 0]
#  [3 0]
#  [6 2]]
# Step 338: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [3 0]
#  [3 0]
#  [6 2]]
# Step 339: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [3 0]
#  [3 0]
#  [6 2]]
# Step 340: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [3 0]
#  [3 0]
#  [6 2]]
# Step 341: User associations (user x radio):
# [[3 5]
#  [6 3]
#  [3 0]
#  [3 0]
#  [6 2]]
# Step 342: User associations (user x radio):
# [[3 5]
#  [6 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 343: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 344: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 345: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 346: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 347: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 348: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 349: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 350: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 351: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 352: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 353: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 354: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 355: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 356: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 357: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 358: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 0]
#  [3 0]
#  [6 2]]
# Step 359: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [6 4]
#  [3 0]
#  [6 2]]
# Step 360: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [2 4]
#  [3 0]
#  [6 2]]
# Step 361: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [2 4]
#  [3 0]
#  [6 2]]
# Step 362: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [2 4]
#  [3 0]
#  [6 2]]
# Step 363: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [2 4]
#  [3 0]
#  [6 2]]
# Step 364: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [2 4]
#  [3 0]
#  [6 2]]
# Step 365: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [2 4]
#  [3 0]
#  [6 2]]
# Step 366: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [2 4]
#  [3 0]
#  [6 2]]
# Step 367: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 368: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 369: User associations (user x radio):
# [[3 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 370: User associations (user x radio):
# [[4 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 371: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 372: User associations (user x radio):
# [[4 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 373: User associations (user x radio):
# [[4 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 374: User associations (user x radio):
# [[4 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 375: User associations (user x radio):
# [[4 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 376: User associations (user x radio):
# [[4 5]
#  [1 4]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 377: User associations (user x radio):
# [[4 5]
#  [1 3]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 378: User associations (user x radio):
# [[3 5]
#  [1 3]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 379: User associations (user x radio):
# [[3 5]
#  [1 3]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 380: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 381: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 382: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 383: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 384: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 385: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 386: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 387: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 388: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 389: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 390: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 391: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 392: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 393: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 394: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 395: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 396: User associations (user x radio):
# [[3 6]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 397: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 398: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 399: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 400: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 401: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 402: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 403: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 404: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 405: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 406: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 407: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 408: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 409: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 410: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 411: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 412: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 413: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 414: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 415: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 416: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 417: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 418: User associations (user x radio):
# [[3 5]
#  [6 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 419: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 420: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 421: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 422: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 423: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 424: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 425: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 426: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 427: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 428: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 429: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 430: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 431: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 432: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 433: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 434: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 435: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 436: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 437: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 438: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 439: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 440: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 441: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 442: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 443: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 444: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 445: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 446: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 447: User associations (user x radio):
# [[3 6]
#  [2 6]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 448: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 0]]
# Step 449: User associations (user x radio):
# [[1 5]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 0]]
# Step 450: User associations (user x radio):
# [[1 5]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 0]]
# Step 451: User associations (user x radio):
# [[1 5]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 0]]
# Step 452: User associations (user x radio):

#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1048: User associations (user x radio):
# [[3 5]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 0]]
# Step 1049: User associations (user x radio):
# [[1 5]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 0]]
# Step 1050: User associations (user x radio):
# [[1 5]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 0]]
# Step 1051: User associations (user x radio):
# [[1 5]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 0]]
# Step 1052: User associations (user x radio):
# [[1 5]
#  [2 6]
#  [3 4]
#  [1 0]
#  [6 0]]
# Step 1053: User associations (user x radio):
# [[1 2]
#  [2 6]
#  [3 4]
#  [1 0]
#  [6 0]]
# Step 1054: User associations (user x radio):
# [[1 2]
#  [2 6]
#  [3 4]
#  [1 0]
#  [6 0]]
# Step 1055: User associations (user x radio):
# [[1 2]
#  [2 6]
#  [3 4]
#  [1 0]
#  [6 0]]
# Step 1056: User associations (user x radio):
# [[1 2]
#  [2 6]
#  [3 4]
#  [1 0]
#  [6 0]]
# Step 1057: User associations (user x radio):
# [[1 2]
#  [2 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1058: User associations (user x radio):
# [[1 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1059: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1060: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1061: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1062: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1063: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1064: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1065: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1066: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1067: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 6]]
# Step 1068: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1069: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1070: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1071: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1072: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1073: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1074: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1075: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1076: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1077: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1078: User associations (user x radio):
# [[2 2]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 2]]
# Step 1079: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 1080: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 1081: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 1082: User associations (user x radio):
# [[2 5]
#  [1 6]
#  [3 4]
#  [3 0]
#  [6 5]]
# Step 1083: User associations (user x radio):
# [[0 5]
#  [1 6]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1084: User associations (user x radio):
# [[0 5]
#  [1 6]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1085: User associations (user x radio):
# [[0 5]
#  [1 6]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1086: User associations (user x radio):
# [[0 5]
#  [1 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1087: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1088: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1089: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1090: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1091: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1092: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1093: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1094: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1095: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1096: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1097: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1098: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1099: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1100: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1101: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1102: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1103: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1104: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1105: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1106: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1107: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1108: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1109: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1110: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1111: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1112: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1113: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1114: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1115: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1116: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1117: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1118: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1119: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 0]]
# Step 1120: User associations (user x radio):
# [[2 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1121: User associations (user x radio):
# [[2 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1122: User associations (user x radio):
# [[2 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1123: User associations (user x radio):
# [[2 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1124: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1125: User associations (user x radio):
# [[0 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1126: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1127: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1128: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1129: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1130: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1131: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1132: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1133: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1134: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1135: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1136: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1137: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1138: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1139: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1140: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1141: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1142: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1143: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1144: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1145: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1146: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1147: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1148: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1149: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1150: User associations (user x radio):
# [[3 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1151: User associations (user x radio):
# [[2 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1152: User associations (user x radio):
# [[2 5]
#  [2 0]
#  [3 0]
#  [3 0]
#  [6 5]]
# Step 1153: User associations (user x radio):
# [[2 6]
#  [2 0]
#  [3 0]
#  [1 0]
#  [6 5]]
# Step 1154: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1155: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1156: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1157: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1158: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1159: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1160: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1161: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1162: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1163: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1164: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1165: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1166: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1167: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1168: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1169: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1170: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1171: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1172: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1173: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1174: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1175: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1176: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1177: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1178: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1179: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1180: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1181: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1182: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1183: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1184: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1185: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1186: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1187: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1188: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1189: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1190: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1191: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1192: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1193: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1194: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1195: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1196: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1197: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1198: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Step 1199: User associations (user x radio):
# [[2 6]
#  [2 6]
#  [3 0]
#  [1 0]
#  [6 4]]
# Episode finished. Reward: 2256848484.560903

# %%
episode_rewards
# Out:
# [13458409479.18913, 2256848484.560903]
